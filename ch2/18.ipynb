# %%
FILE_PATH = "data/popular-names.txt"

with open(FILE_PATH, "r") as f:
    name_list = f.readlines()

name_list.sort(key = lambda x: x[2], reverse=True)
name_list = list(map(lambda x: x.replace("\t"," "), name_list))
name_list

# #P.10 明確な単語を選ぶ
# Out:
# ['Amy F 21464 1969\n',
#  'Amy F 25209 1970\n',
#  'Amy F 26237 1971\n',
#  'Amy F 25873 1972\n',
#  'Amy F 26964 1973\n',
#  'Amy F 29565 1974\n',
#  'Amy F 32251 1975\n',
#  'Amy F 31341 1976\n',
#  'Amy F 26732 1977\n',
#  'Amy F 23212 1978\n',
#  'Amy F 21615 1979\n',
#  'Amy F 19835 1980\n',
#  'Amy F 20343 1981\n',
#  'Crystal F 19104 1982\n',
#  'Amy F 18803 1982\n',
#  'Taylor F 21267 1993\n',
#  'Taylor F 20733 1994\n',
#  'Taylor F 20425 1995\n',
#  'Taylor F 19152 1996\n',
#  'Taylor F 19502 1997\n',
#  'Taylor F 18572 1998\n',
#  'Taylor F 16905 1999\n',
#  'Taylor F 15078 2000\n',
#  'Jayden M 17288 2009\n',
#  'Jayden M 17179 2010\n',
#  'Jayden M 16992 2011\n',
#  'Jayden M 16127 2012\n',
#  'Jayden M 14766 2013\n',
#  'Edward M 2177 1881\n',
#  'Edward M 2125 1887\n',
#  'Edward M 2299 1889\n',
#  'Edward M 2309 1893\n',
#  'Edward M 2203 1895\n',
#  'Edward M 2296 1896\n',
#  'Edward M 2121 1897\n',
#  'Edward M 2337 1898\n',
#  'Edward M 1901 1899\n',
# ...
